# %% [markdown]
# 6/09/2018
# results of applying cos similarity model to babi
#
# train model with 1000 examples (0% dropout rate)
#
# test accuracy: 15-20%
# ![loss_180906-1221.png](attachment:loss_180906-1221.png)
#
#
#
# train model with 10000 examples (30% dropout rate)
#
# test accuracy: 15-20%
# ![loss_180906-1402.png](attachment:loss_180906-1402.png)
#
#
# loss decreases and stabilizes around 0.5
